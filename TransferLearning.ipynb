# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitaSK/AB-Image-Classification/blob/BitWhisperer/TransferLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using pretrained model and using new output layer with the required number of classes

# %%
from keras.backend import clear_session
clear_session()

# %%
# importing libraries

import os
import pathlib
import random
import numpy as np
import matplotlib.pyplot as plt

import zipfile
import requests
import glob as glob

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from tensorflow.keras.utils import image_dataset_from_directory

from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from dataclasses import dataclass

from zipfile import ZipFile
from urllib.request import urlretrieve
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
@dataclass(frozen=True)
class DatasetConfig:
    NUM_CLASSES: int = 10
    IMG_HEIGHT:  int = 32
    IMG_WIDTH:   int = 32
    CHANNELS:    int = 3


@dataclass(frozen=True)
class TrainingConfig:
    EPOCHS:           int   = 50
    LEARNING_RATE:    float = 0.0001
    DROPOUT:          float = 0.5
    LAYERS_FINE_TUNE: int   = 15

# %%
SEED_VALUE = 41

# Fix seed to make training deterministic.
random.seed(SEED_VALUE)
np.random.seed(SEED_VALUE)
tf.random.set_seed(SEED_VALUE)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns

# Load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# separating training and validation set
X_valid = X_train[:10000]
X_train = X_train[10000:]

y_valid = y_train[:10000]
y_train = y_train[10000:]


#normalize the data by dividing by 255 to scale the pixel values between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_valid = X_valid.astype('float32') / 255


# Convert the labels to one-hot encoded form.
y_train = tf.keras.utils.to_categorical(y_train, DatasetConfig.NUM_CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, DatasetConfig.NUM_CLASSES)
y_valid = tf.keras.utils.to_categorical(y_valid, DatasetConfig.NUM_CLASSES)

print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# fine tuning
# we need to redefine the classifier
# Load the VGG16 model with pretrained ImageNet weights, excluding the top (fully connected) layers
input_shape = (DatasetConfig.IMG_HEIGHT, DatasetConfig.IMG_WIDTH, DatasetConfig.CHANNELS)

base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=input_shape
)

base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 1, 1, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Freeze the Initial Layers in the Convolutional Base
# Set all layers in the convolutional base to Trainable (will FREEZE initial layers further below)
base_model.trainable = True

# Specify the number of layers to fine tune at the end of the convolutional base.
num_layers_fine_tune = TrainingConfig.LAYERS_FINE_TUNE
num_layers = len(base_model.layers)

# Freeze the initial layers in the convolutional base.
for model_layer in base_model.layers[: num_layers - num_layers_fine_tune]:
    print(f"FREEZING LAYER: {model_layer}")
    model_layer.trainable = False

print("\n")
print(f"Configured to fine tune the last {num_layers_fine_tune} convolution layers")
print("\n")
base_model.summary()
# Out:
# FREEZING LAYER: <InputLayer name=input_layer, built=True>
# FREEZING LAYER: <Conv2D name=block1_conv1, built=True>
# FREEZING LAYER: <Conv2D name=block1_conv2, built=True>
# FREEZING LAYER: <MaxPooling2D name=block1_pool, built=True>
#
#
# Configured to fine tune the last 15 convolution layers
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 1, 1, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,675,968 (55.98 MB)
#  Non-trainable params: 38,720 (151.25 KB)

# %%
# Add the Classifier to Complete the Model
def create_model():
  model = Sequential([
    base_model,  # Add the pretrained model (frozen initially)
    layers.GlobalAveragePooling2D(),  # Convert 4D tensor to 2D
    layers.Dense(256, activation='relu'),  # Fully connected layer
    layers.Dropout(TrainingConfig.DROPOUT),  # Prevent overfitting
    layers.Dense(DatasetConfig.NUM_CLASSES, activation='softmax')  # CIFAR-10 has 10 classes
  ])

  # Compile the model
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=TrainingConfig.LEARNING_RATE),
      loss='categorical_crossentropy',
      metrics=['accuracy']
  )

  return model

# Create a basic model instance
model = create_model()

# checkpoint
checkpoint_path = "training_1/best_model_transfer_learning.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    verbose=1
)

# checkpoint = ModelCheckpoint(
#     filepath='best_model_transfer_learning.keras',
#      monitor="val_loss",
#     mode="min",
#      save_best_only=True, verbose=1
# )

# early stop to improve accuracy
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)

#Train the model
training_results = model.fit(
    X_train,
    y_train,
    epochs=TrainingConfig.EPOCHS,
    validation_data=(X_valid, y_valid),
    callbacks=[cp_callback, early_stopping]
)
# Out:
# Epoch 1/50
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5181 - loss: 1.3856
# Epoch 1: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.5184 - loss: 1.3848 - val_accuracy: 0.7601 - val_loss: 0.7346
# Epoch 2/50
# 1246/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7939 - loss: 0.6423
# Epoch 2: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7940 - loss: 0.6421 - val_accuracy: 0.7965 - val_loss: 0.6325
# Epoch 3/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8495 - loss: 0.4649
# Epoch 3: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8495 - loss: 0.4648 - val_accuracy: 0.8095 - val_loss: 0.6271
# Epoch 4/50
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8934 - loss: 0.3417
# Epoch 4: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8934 - loss: 0.3417 - val_accuracy: 0.8195 - val_loss: 0.6372
# Epoch 5/50
# 1242/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9150 - loss: 0.2671
# Epoch 5: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9151 - loss: 0.2670 - val_accuracy: 0.8158 - val_loss: 0.7261
# Epoch 6/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9371 - loss: 0.2023
# Epoch 6: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9371 - loss: 0.2023 - val_accuracy: 0.8302 - val_loss: 0.6144
# Epoch 7/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9535 - loss: 0.1504
# Epoch 7: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9535 - loss: 0.1503 - val_accuracy: 0.8455 - val_loss: 0.6168
# Epoch 8/50
# 1243/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9616 - loss: 0.1267
# Epoch 8: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9616 - loss: 0.1267 - val_accuracy: 0.8380 - val_loss: 0.6590
# Epoch 9/50
# 1247/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.1014
# Epoch 9: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9688 - loss: 0.1014 - val_accuracy: 0.8359 - val_loss: 0.7139
# Epoch 10/50
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9743 - loss: 0.0856
# Epoch 10: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9743 - loss: 0.0856 - val_accuracy: 0.8279 - val_loss: 0.8156
# Epoch 11/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0782
# Epoch 11: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9773 - loss: 0.0782 - val_accuracy: 0.8369 - val_loss: 0.7301
# Epoch 12/50
# 1243/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9775 - loss: 0.0731
# Epoch 12: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9775 - loss: 0.0731 - val_accuracy: 0.8518 - val_loss: 0.6734
# Epoch 13/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0553
# Epoch 13: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9837 - loss: 0.0553 - val_accuracy: 0.8428 - val_loss: 0.7187
# Epoch 14/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9825 - loss: 0.0592
# Epoch 14: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9825 - loss: 0.0593 - val_accuracy: 0.8413 - val_loss: 0.7734
# Epoch 15/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.0504
# Epoch 15: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9845 - loss: 0.0504 - val_accuracy: 0.8433 - val_loss: 0.7985
# Epoch 16/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9842 - loss: 0.0515
# Epoch 16: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9842 - loss: 0.0515 - val_accuracy: 0.8404 - val_loss: 0.8982
# Epoch 17/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9868 - loss: 0.0503
# Epoch 17: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9868 - loss: 0.0503 - val_accuracy: 0.8459 - val_loss: 0.8059
# Epoch 18/50
# 1246/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9863 - loss: 0.0485
# Epoch 18: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9863 - loss: 0.0485 - val_accuracy: 0.8478 - val_loss: 0.7631
# Epoch 19/50
# 1247/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0401
# Epoch 19: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9879 - loss: 0.0402 - val_accuracy: 0.8369 - val_loss: 0.7686
# Epoch 20/50
# 1244/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.0472
# Epoch 20: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9865 - loss: 0.0472 - val_accuracy: 0.8376 - val_loss: 0.8735
# Epoch 21/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 0.0431
# Epoch 21: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9870 - loss: 0.0431 - val_accuracy: 0.8430 - val_loss: 0.8361
# Epoch 22/50
# 1247/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.0314
# Epoch 22: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9903 - loss: 0.0314 - val_accuracy: 0.8545 - val_loss: 0.8704
# Epoch 23/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.0383
# Epoch 23: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9893 - loss: 0.0383 - val_accuracy: 0.8409 - val_loss: 0.9297
# Epoch 24/50
# 1246/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9882 - loss: 0.0384
# Epoch 24: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9882 - loss: 0.0384 - val_accuracy: 0.8409 - val_loss: 0.8353
# Epoch 25/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.0347
# Epoch 25: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9909 - loss: 0.0347 - val_accuracy: 0.8528 - val_loss: 0.8243
# Epoch 26/50
# 1243/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0271
# Epoch 26: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9920 - loss: 0.0271 - val_accuracy: 0.8388 - val_loss: 1.0051
# Epoch 27/50
# 1243/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9897 - loss: 0.0389
# Epoch 27: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9897 - loss: 0.0389 - val_accuracy: 0.8433 - val_loss: 0.8793
# Epoch 28/50
# 1245/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0359
# Epoch 28: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9898 - loss: 0.0358 - val_accuracy: 0.8470 - val_loss: 0.9371
# Epoch 29/50
# 1242/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9921 - loss: 0.0285
# Epoch 29: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9921 - loss: 0.0286 - val_accuracy: 0.8433 - val_loss: 0.9526
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.0308
# Epoch 30: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9909 - loss: 0.0308 - val_accuracy: 0.8367 - val_loss: 1.0807
# Epoch 31/50
# 1248/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.0381
# Epoch 31: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9885 - loss: 0.0381 - val_accuracy: 0.8394 - val_loss: 0.9854
# Epoch 32/50
# 1242/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.0270
# Epoch 32: saving model to training_1/best_model_transfer_learning.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9928 - loss: 0.0271 - val_accuracy: 0.8397 - val_loss: 0.8964

# %%
os.listdir(checkpoint_dir)
# Out:
# ['best_model_transfer_learning.weights.h5']

# %%
def plot_results(metrics, ylabel=None, ylim=None, metric_name=None, color=None):
    fig, ax = plt.subplots(figsize=(15, 4))

    if not (isinstance(metric_name, list) or isinstance(metric_name, tuple)):
        metrics = [metrics,]
        metric_name = [metric_name,]

    for idx, metric in enumerate(metrics):
        ax.plot(metric, color=color[idx])

    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.title(ylabel)
    plt.xlim([0, len(training_results.history['loss'])])
    plt.ylim(ylim)
    # Tailor x-axis tick marks
    ax.xaxis.set_major_locator(MultipleLocator(5))
    ax.xaxis.set_major_formatter(FormatStrFormatter("%d"))
    ax.xaxis.set_minor_locator(MultipleLocator(1))
    plt.grid(True)
    plt.legend(metric_name)
    plt.show()
    plt.close()

# %%
# Retrieve training results.
train_loss = training_results.history["loss"]
train_acc  = training_results.history["accuracy"]
valid_loss = training_results.history["val_loss"]
valid_acc  = training_results.history["val_accuracy"]

plot_results(
    [train_loss, valid_loss],
    ylabel="Loss",
    ylim=[0.0, 3.0],
    metric_name=["Training Loss", "Validation Loss"],
    color=["g", "b"],
)

plot_results(
    [train_acc, valid_acc],
    ylabel="Accuracy",
    ylim=[0.0, 1.0],
    metric_name=["Training Accuracy", "Validation Accuracy"],
    color=["g", "b"],
)

# %%
# Create a basic model instance
model = create_model()

# Evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 313/313 - 2s - 7ms/step - accuracy: 0.0177 - loss: 4.4618
# Untrained model, accuracy:  1.77%

# %%
# Loads the weights
model.load_weights(checkpoint_path)

# Re-evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 313/313 - 1s - 2ms/step - accuracy: 0.8432 - loss: 0.9214
# Restored model, accuracy: 84.32%

# %%
# Continue training from the last saved epoch
history = model.fit(X_train, y_train,
                    validation_data=(X_valid, y_valid),
                    epochs=30,
                    initial_epoch=len(training_results.history['loss']) + 1,  # Start from the last epoch,
                    callbacks=[cp_callback, early_stopping]
                    )

# %%
# Re-evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8432 - loss: 0.9214
# Restored model, accuracy: 84.32%

# %%
valid_loss, valid_accuracy = model.evaluate(X_valid, y_valid)
print(f"Model valid accuracy: {valid_accuracy*100.:.3f}, Model valid loss: {valid_loss}")
print("\n\n")
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Model test accuracy: {test_accuracy*100.:.3f}, Model test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8453 - loss: 0.8593
# Model valid accuracy: 83.970, Model valid loss: 0.8963670134544373
#
#
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8423 - loss: 0.9367
# Model test accuracy: 84.320, Model test loss: 0.9214360117912292

# %%
train_loss, train_accuracy = model.evaluate(X_train, y_train)
print(train_loss)
print(train_accuracy)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9937 - loss: 0.0188
# 0.018419062718749046
# 0.9941750168800354

# %%
# confusion matrix
y_pred = model.predict(X_test)

predictions = np.argmax(y_pred, axis=1)
gt = np.argmax(y_test, axis=1)
cm = confusion_matrix(gt, predictions)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix after dropout')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
import matplotlib.pyplot as plt

# Labels for the bar chart
labels = ['Training', 'Validation', 'Test']
# Accuracy values
accuracies = [train_accuracy, valid_accuracy, test_accuracy]

# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(labels, accuracies, color=['blue', 'orange', 'green'])

# Add title and labels
plt.title('Training, Validation, and Test Accuracy', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
plt.ylim([0, 1])  # Set y-axis from 0 to 1 (for percentages)

# Add accuracy values on top of the bars
for i, acc in enumerate(accuracies):
    plt.text(i, acc + 0.01, f'{acc:.2%}', ha='center', fontsize=12)

# Show the plot
plt.show()

# %%
valid_loss, valid_accuracy = model.evaluate(X_valid, y_valid)
print(f"Model valid accuracy: {valid_accuracy*100.:.3f}, Model valid loss: {valid_loss}")
print("\n\n")
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Model test accuracy: {test_accuracy*100.:.3f}, Model test loss: {test_loss}")

train_loss, train_accuracy = model.evaluate(X_train, y_train)
print(train_loss)
print(train_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8453 - loss: 0.8593
# Model valid accuracy: 83.970, Model valid loss: 0.8963670134544373
#
#
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8423 - loss: 0.9367
# Model test accuracy: 84.320, Model test loss: 0.9214360117912292
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9937 - loss: 0.0188
# 0.018419062718749046
# 0.9941750168800354
